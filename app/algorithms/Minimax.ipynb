# %%
import chess

# %%
BOARD_DIMENSION = 8
MAX_DEPTH = 4
VALUE_MAP = {
    "p": 10,
    "n": 30,
    "b": 30,
    "r": 50,
    "q": 90,
    "k": 900
}

# %%
class MinimaxSearch:

    def get_move(self, initial_state: chess.Board) -> chess.Move:
        """Return the best move from the state "initial_state"
        Args:
            initial_state (chess.Board): _description_
        Returns:
            chess.Move: the best move
        """
        return self.minimax(initial_state, MAX_DEPTH)

    def to_move(self, state: chess.Board) -> chess.COLORS:
        """The player whose turn it is to move in state "state"
        Args:
            state (chess.Board): the current state of the game
        Returns:
            chess.COLORS: the player whose turn it is to move
        """
        return state.turn
    
    def action(self, state: chess.Board) -> list[chess.Move]:
        """the set of possible moves in state "state"

        Args:
            state (chess.Board): the current state of the game
        Returns:
            list[chess.Move]: the set of possible moves
        """
        return state.legal_moves

    def result(self, state: chess.Board, action: chess.Move) -> chess.Board:
        """The transion model which defines the state resulting 
        from taking the action "action" in state "state"

        Args:
            state (chess.Board): the current state of the game
            action (chess.Move): the action to be taken
        Returns:
            chess.Board: the resulting state
        """
        resulting_state = state.copy()
        resulting_state.push(action)
        return resulting_state

    def is_terminal(self, board: chess.Board, depth: int) -> bool:
        """Return True if the state "board" is a terminal state,
        False otherwise
        """
        if depth == 0 or board.is_game_over():
            return True
        return False

    def utility(self, board: chess.Board, player: chess.COLORS) -> int:
        """Return the utility/objective/heuristic value of the state "board" for the
        player "player" when the game is over

        Args:
            board (chess.Board): the current state of the game
            player (chess.COLORS): the player who holds the turn in the terminal state
        
        Returns:
            int: the utility/objective value of the state
            (positive for a win, negative for a loss, 0 for a draw)
        """
        total_value = 0
        for i in range(0, 8):
            for j in range(0, 8):
                square = board.piece_at(self._convert_to_square(i, j))
                if (square != None and square.color == player):
                    # Get the piece type
                    piece_type = square.piece_type
                    # Get the piece value
                    piece_value = VALUE_MAP[chess.PIECE_SYMBOLS[piece_type]]
                    # Add the piece value to the total value
                    total_value += piece_value
                elif (square != None and square.color != player):
                    # Get the piece type
                    piece_type = square.piece_type
                    # Get the piece value
                    piece_value = VALUE_MAP[chess.PIECE_SYMBOLS[piece_type]]
                    # Subtract the piece value from the total value
                    total_value -= piece_value
        return total_value

    def minimax(self, board: chess.Board, depth: int) -> chess.Move:
        """Return the minimax value of the state "board" with depth "depth"
        Args:
            board (chess.Board): the current state of the game
            depth (int): the depth of the search tree
        Returns:
            chess.Move: the best move
        """
        (_, move) = self.max_value(board, depth)
        return move if move != None else chess.Move.null()

    def max_value(self, board: chess.Board, depth: int) -> tuple:
        """Return the max value of the state "board" with depth "depth"
        Args:
            board (chess.Board): the current state of the game
            depth (int): the depth of the search tree
        Returns:
            tuple(int, chess.Move): the max value of the state and the move that leads to it
        """
        if self.is_terminal(board, depth):
            return (self.utility(board, self.to_move(board)), None)
        v = -float('inf')
        move = None
        for a in self.action(board):
            (v2, a2) = self.min_value(self.result(board, a), depth - 1)
            if v2 > v:
                (v, move) = (v2, a)
        return (v, move)

    def min_value(self, board: chess.Board, depth: int) -> tuple:
        """Return the min value of the state "board" with depth "depth"
        Args:
            board (chess.Board): the current state of the game
            depth (int): the depth of the search tree
        Returns:
            tuple(int, chess.Move): the min value of the state and the move that leads to it
        """
        if self.is_terminal(board, depth):
            return (self.utility(board, self.to_move(board)), None)
        v = float('inf')
        move = None       
        for a in self.action(board):
            (v2, a2) = self.max_value(self.result(board, a), depth - 1)
            if v2 < v:
                (v, move) = (v2, a)
        return (v, move)

    def _convert_to_square(self, row: int, col: int) -> chess.Square:
        return chess.SQUARES[row*BOARD_DIMENSION + col]

# %%
board = chess.Board()
random = MinimaxSearch()

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/7N/PPPPPPPP/RNBQKB1R b KQkq - 1 1')

# %%
board.push(random.get_move(board))
board
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/tom107/3106Project/Minimax.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=0'>1</a> board.push(random.get_move(board))
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=1'>2</a> board
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 3' in MinimaxSearch.get_move(self, initial_state)
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=2'>3</a> def get_move(self, initial_state: chess.Board) -> chess.Move:
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=3'>4</a>     """Return the best move from the state "initial_state"
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=4'>5</a>     Args:
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=5'>6</a>         initial_state (chess.Board): _description_
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=6'>7</a>     Returns:
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=7'>8</a>         chess.Move: the best move
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=8'>9</a>     """
# ---> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=9'>10</a>     return self.minimax(initial_state, MAX_DEPTH)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 3' in MinimaxSearch.minimax(self, board, depth)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=84'>85</a> def minimax(self, board: chess.Board, depth: int) -> chess.Move:
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=85'>86</a>     """Return the minimax value of the state "board" with depth "depth"
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=86'>87</a>     Args:
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=87'>88</a>         board (chess.Board): the current state of the game
#    (...)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=90'>91</a>         chess.Move: the best move
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=91'>92</a>     """
# ---> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=92'>93</a>     (_, move) = self.max_value(board, depth)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=93'>94</a>     return move if move != None else chess.Move.null()
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 3' in MinimaxSearch.max_value(self, board, depth)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=106'>107</a> move = None
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=107'>108</a> for a in self.action(board):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=108'>109</a>     (v2, a2) = self.min_value(self.result(board, a), depth - 1)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=109'>110</a>     if v2 > v:
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=110'>111</a>         (v, move) = (v2, a)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 3' in MinimaxSearch.min_value(self, board, depth)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=124'>125</a> move = None
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=125'>126</a> for a in self.action(board):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=126'>127</a>     (v2, a2) = self.max_value(self.result(board, a), depth - 1)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=127'>128</a>     if v2 < v:
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=128'>129</a>         (v, move) = (v2, a)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 3' in MinimaxSearch.max_value(self, board, depth)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=106'>107</a> move = None
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=107'>108</a> for a in self.action(board):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=108'>109</a>     (v2, a2) = self.min_value(self.result(board, a), depth - 1)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=109'>110</a>     if v2 > v:
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=110'>111</a>         (v, move) = (v2, a)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 3' in MinimaxSearch.min_value(self, board, depth)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=124'>125</a> move = None
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=125'>126</a> for a in self.action(board):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=126'>127</a>     (v2, a2) = self.max_value(self.result(board, a), depth - 1)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=127'>128</a>     if v2 < v:
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=128'>129</a>         (v, move) = (v2, a)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 3' in MinimaxSearch.max_value(self, board, depth)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=96'>97</a> """Return the max value of the state "board" with depth "depth"
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=97'>98</a> Args:
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=98'>99</a>     board (chess.Board): the current state of the game
#    (...)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=101'>102</a>     tuple(int, chess.Move): the max value of the state and the move that leads to it
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=102'>103</a> """
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=103'>104</a> if self.is_terminal(board, depth):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=104'>105</a>     return (self.utility(board, self.to_move(board)), None)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=105'>106</a> v = -float('inf')
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=106'>107</a> move = None
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 3' in MinimaxSearch.utility(self, board, player)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=65'>66</a> for i in range(0, 8):
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=66'>67</a>     for j in range(0, 8):
# ---> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=67'>68</a>         square = board.piece_at(self._convert_to_square(i, j))
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=68'>69</a>         if (square != None and square.color == player):
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=69'>70</a>             # Get the piece type
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000002?line=70'>71</a>             piece_type = square.piece_type
#
# File ~/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py:678, in BaseBoard.piece_at(self, square)
#     <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=675'>676</a> if piece_type:
#     <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=676'>677</a>     mask = BB_SQUARES[square]
# --> <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=677'>678</a>     color = bool(self.occupied_co[WHITE] & mask)
#     <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=678'>679</a>     return Piece(piece_type, color)
#     <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=679'>680</a> else:
#
# KeyboardInterrupt:

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/5N2/8/PPPPPPPP/RNBQKB1R w KQkq - 2 3')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/5N2/5P2/PPPPP1PP/RNBQKB1R b KQkq - 0 3')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbr1/ppppppp1/5n1p/8/5N2/5P2/PPPPP1PP/RNBQKB1R w KQq - 1 4')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbr1/ppppppp1/5n1p/8/8/5P1N/PPPPP1PP/RNBQKB1R b KQq - 2 4')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/8/5P1N/PPPPP1PP/RNBQKB1R w KQq - 3 5')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/5N2/5P2/PPPPP1PP/RNBQKB1R b KQq - 4 5')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbr1/ppppppp1/5n1p/8/5N2/5P2/PPPPP1PP/RNBQKB1R w KQq - 5 6')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbr1/ppppppp1/5n1p/8/8/5P1N/PPPPP1PP/RNBQKB1R b KQq - 6 6')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/8/5P1N/PPPPP1PP/RNBQKB1R w KQq - 7 7')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/5N2/5P2/PPPPP1PP/RNBQKB1R b KQq - 8 7')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbr1/ppppppp1/5n1p/8/5N2/5P2/PPPPP1PP/RNBQKB1R w KQq - 9 8')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbr1/ppppppp1/5n1p/8/8/5P1N/PPPPP1PP/RNBQKB1R b KQq - 10 8')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/8/5P1N/PPPPP1PP/RNBQKB1R w KQq - 11 9')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/5N2/5P2/PPPPP1PP/RNBQKB1R b KQq - 12 9')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbr1/ppppppp1/5n1p/8/5N2/5P2/PPPPP1PP/RNBQKB1R w KQq - 13 10')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkbr1/ppppppp1/5n1p/8/8/5P1N/PPPPP1PP/RNBQKB1R b KQq - 14 10')

# %%
board.push(random.get_move(board))
board
# Out:
# Board('rnbqkb1r/ppppppp1/5n1p/8/8/5P1N/PPPPP1PP/RNBQKB1R w KQq - 15 11')

# %%
board.push(random.get_move(board))
board
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 board.push(random.get_move(board))
#       2 board
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 5' in Random.get_move(self, initial_state)
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=2'>3</a> def get_move(self, initial_state: chess.Board) -> chess.Move:
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=3'>4</a>     """Return the best move from the state "initial_state"
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=4'>5</a>     Args:
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=5'>6</a>         initial_state (chess.Board): _description_
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=6'>7</a>     Returns:
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=7'>8</a>         chess.Move: the best move
#       <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=8'>9</a>     """
# ---> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=9'>10</a>     return self.minimax(initial_state, MAX_DEPTH)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 5' in Random.minimax(self, board, depth)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=85'>86</a> def minimax(self, board: chess.Board, depth: int) -> chess.Move:
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=86'>87</a>     """Return the minimax value of the state "board" with depth "depth"
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=87'>88</a>     Args:
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=88'>89</a>         board (chess.Board): the current state of the game
#    (...)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=91'>92</a>         chess.Move: the best move
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=92'>93</a>     """
# ---> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=93'>94</a>     (_, move) = self.max_value(board, depth)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=94'>95</a>     return move if move != None else chess.Move.null()
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 5' in Random.max_value(self, board, depth)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=107'>108</a> move = None
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=108'>109</a> for a in self.action(board):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=109'>110</a>     (v2, a2) = self.min_value(self.result(board, a), depth - 1)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=110'>111</a>     if v2 > v:
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=111'>112</a>         (v, move) = (v2, a)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 5' in Random.min_value(self, board, depth)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=125'>126</a> move = None
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=126'>127</a> for a in self.action(board):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=127'>128</a>     (v2, a2) = self.max_value(self.result(board, a), depth - 1)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=128'>129</a>     if v2 < v:
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=129'>130</a>         (v, move) = (v2, a)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 5' in Random.max_value(self, board, depth)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=107'>108</a> move = None
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=108'>109</a> for a in self.action(board):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=109'>110</a>     (v2, a2) = self.min_value(self.result(board, a), depth - 1)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=110'>111</a>     if v2 > v:
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=111'>112</a>         (v, move) = (v2, a)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 5' in Random.min_value(self, board, depth)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=125'>126</a> move = None
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=126'>127</a> for a in self.action(board):
# --> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=127'>128</a>     (v2, a2) = self.max_value(self.result(board, a), depth - 1)
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=128'>129</a>     if v2 < v:
#     <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=129'>130</a>         (v, move) = (v2, a)
#
# /Users/tom107/3106Project/Minimax.ipynb Cell 5' in Random.result(self, state, action)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=30'>31</a> def result(self, state: chess.Board, action: chess.Move) -> chess.Board:
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=31'>32</a>     """The transion model which defines the state resulting
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=32'>33</a>     from taking the action "action" in state "state"
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=33'>34</a>
#    (...)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=38'>39</a>         chess.Board: the resulting state
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=39'>40</a>     """
# ---> <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=40'>41</a>     resulting_state = state.copy()
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=41'>42</a>     resulting_state.push(action)
#      <a href='vscode-notebook-cell:/Users/tom107/3106Project/Minimax.ipynb#ch0000004?line=42'>43</a>     return resulting_state
#
# File ~/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py:3676, in Board.copy(self, stack)
#    <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3673'>3674</a> if stack:
#    <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3674'>3675</a>     stack = len(self.move_stack) if stack is True else stack
# -> <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3675'>3676</a>     board.move_stack = [copy.copy(move) for move in self.move_stack[-stack:]]
#    <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3676'>3677</a>     board._stack = self._stack[-stack:]
#    <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3678'>3679</a> return board
#
# File ~/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py:3676, in <listcomp>(.0)
#    <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3673'>3674</a> if stack:
#    <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3674'>3675</a>     stack = len(self.move_stack) if stack is True else stack
# -> <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3675'>3676</a>     board.move_stack = [copy.copy(move) for move in self.move_stack[-stack:]]
#    <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3676'>3677</a>     board._stack = self._stack[-stack:]
#    <a href='file:///Users/tom107/3106Project/server/venv/lib/python3.9/site-packages/chess/__init__.py?line=3678'>3679</a> return board
#
# File /opt/homebrew/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py:102, in copy(x)
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py?line=99'>100</a> if isinstance(rv, str):
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py?line=100'>101</a>     return x
# --> <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py?line=101'>102</a> return _reconstruct(x, None, *rv)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py:279, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py?line=276'>277</a>     slotstate = None
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py?line=277'>278</a> if state is not None:
# --> <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py?line=278'>279</a>     y.__dict__.update(state)
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py?line=279'>280</a> if slotstate is not None:
#     <a href='file:///opt/homebrew/Cellar/python%403.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/copy.py?line=280'>281</a>     for key, value in slotstate.items():
#
# KeyboardInterrupt:

# %%
board.push(random.get_move(board))
board

# %%
board.push(random.get_move(board))
board

# %%
board.push(random.get_move(board))
board

# %%
board.push(random.get_move(board))
board

# %%
board.push(random.get_move(board))
board

# %%
board.push(random.get_move(board))
board

# %%
board.push(random.get_move(board))
board

# %%
board.push(random.get_move(board))
board

# %%
board.push(random.get_move(board))
board
